# %%
from Explanation.utils import *
from Explanation.SJsrc import *
from Explanation.HKUSTsrc import *

# %%
import sys
class ParseConfigFile(argparse.Action):

    def __call__(self, parser, namespace, filename, option_string=None):

        if not os.path.exists(filename):
            raise ValueError('cannot find config at `%s`'%filename)

        with open(filename) as f:
            config = json.load(f)
            for key, value in config.items():
                setattr(namespace, key, value)
                
def parse_args():
    parser = argparse.ArgumentParser()

    # model
    parser.add_argument('--model_name', default='NRSR')
    parser.add_argument('--model_path', default='.\parameter')
    parser.add_argument('--num_relation', type= int, default=102)
    parser.add_argument('--d_feat', type=int, default=6)
    parser.add_argument('--hidden_size', type=int, default=128)
    parser.add_argument('--num_layers', type=int, default=2)
    parser.add_argument('--dropout', type=float, default=0.1)
    parser.add_argument('--K', type=int, default=1)
    parser.add_argument('--loss_type', default='')
    parser.add_argument('--config', action=ParseConfigFile, default='')
    # for ts lib model
    parser.add_argument('--seq_len', type=int, default=60)
    parser.add_argument('--moving_avg', type=int, default=21)
    parser.add_argument('--output_attention', action='store_true', help='whether to output attention in ecoder')
    parser.add_argument('--embed', type=str, default='timeF',
                        help='time features encoding, options:[timeF, fixed, learned]')
    parser.add_argument('--freq', type=str, default='b',
                        help='freq for time features encoding, options:[s:secondly, t:minutely, h:hourly, d:daily, b:business days, w:weekly, m:monthly], you can also use more detailed freq like 15min or 3h')
    parser.add_argument('--distil', action='store_false',
                        help='whether to use distilling in encoder, using this argument means not using distilling',
                        default=False)
    parser.add_argument('--factor', type=int, default=1, help='attn factor')
    parser.add_argument('--n_heads', type=int, default=1, help='num of heads')
    parser.add_argument('--d_ff', type=int, default=64, help='dimension of fcn')
    parser.add_argument('--activation', type=str, default='gelu', help='activation')
    parser.add_argument('--e_layers', type=int, default=8, help='num of encoder layers')
    parser.add_argument('--top_k', type=int, default=5, help='for TimesBlock')
    parser.add_argument('--pred_len', type=int, default=-1, help='the length of pred squence, in regression set to -1')
    parser.add_argument('--de_norm', default=True, help='de normalize or not')

    # data
    parser.add_argument('--data_set', type=str, default='csi360')
    parser.add_argument('--target', type=str, default='t+0')
    parser.add_argument('--pin_memory', action='store_false', default=True)
    parser.add_argument('--batch_size', type=int, default=-1)  # -1 indicate daily batch
    parser.add_argument('--least_samples_num', type=float, default=1137.0)
    parser.add_argument('--label', default='')  # specify other labels
    parser.add_argument('--start_date', default='2019-01-01')
    parser.add_argument('--end_date', default='2019-01-05')

    # input for csi 300
    parser.add_argument('--data_root', default='.\Data')
    parser.add_argument('--market_value_path', default= '.\Data\csi300_market_value_07to20.pkl')
    parser.add_argument('--stock2concept_matrix', default='.\Data\csi300_stock2concept.npy')
    parser.add_argument('--stock2stock_matrix', default='.\Data\csi300_multi_stock2stock_hidy_2024.npy')


    parser.add_argument('--stock_index', default='.\Data\csi300_stock_index_2024.npy')
    parser.add_argument('--model_dir', default='.\parameter')
    parser.add_argument('--events_files', default='.\event_data_sigle_stock.json')

    parser.add_argument('--overwrite', action='store_true', default=False)
    parser.add_argument('--device', default='cpu')
    parser.add_argument('--relation_name_list_file', default=r'.\Data\new_relation_name_list2024.json')
  
    filtered_args = [arg for arg in sys.argv if not arg.startswith('-f') and not arg.endswith('.json')]
    args = parser.parse_args(filtered_args[1:])  # Skip the script name
    return args

# %%
args = parse_args()
args.start_date = '2024-04-10'
args.end_date = '2024-04-11' # 输入查询日期
args.check_stock_list = None # 输入待查股票列表，如果输入None则查询CSI300所有股票
args.model_name =  'NRSR' #基于知识的股票预测模型
events_files = args.events_files

# %%
import json
with open(events_files, 'r', encoding='utf-8') as f: # 读入事件文件
    events_data = json.load(f)

# %%
from Explanation.ExplanationInterface import run_input_gradient_explanation
args.explainer = 'inputGradientExplainer'
exp_result_dict, sorted_stock_rank, _ = run_input_gradient_explanation(args, events_data)
print(exp_result_dict) # 输出解释结果
print(sorted_stock_rank) # 股票排名
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  2.58it/s]
# {'2024-04-10': {'SH600000': {'pred_result': -0.03337288, 'SZ001979': {'total_score': 0.5378007, 'relation': ['同行业'], 'events': {}}, 'SZ002142': {'total_score': 0.5145984, 'relation': ['同行业'], 'events': {'2024-02-12': ['35股获券商买入评级 宁波银行目标涨幅达105.63%']}}, 'SZ000001': {'total_score': 0.51399857, 'relation': ['股份制银行Ⅲ', '同行业'], 'events': {'2024-02-21': ['平安银行突然拉升涨停 该行投资者热线：无应披露而未披露信息', '平安银行涨停 成交额超35亿元', '平安银行巨量涨停 国泰君安上海分公司买入2.16亿元', '平安银行盘中涨停', '大金融板块持续走高 平安银行涨超8%', '平安银行行长特别助理蔡新发离职 公茂江拟任上海分行行长', '平安银行今日涨停 方新侠席位净买入1.31亿元', '平安银行回应涨停：目前无应披露而未披露信息', '银行股震荡拉升，中国银行、农业银行再创历史新高，平安银行、成都银行、齐鲁银行涨超2%'], '2024-02-19': ['平安银行变阵：架构改革路线图浮出水面 管理干部发生批量变动'], '2024-02-22': ['平安银行涨停领涨 银行股估值修复持续演绎']}}}, 'SH600009': {'pred_result': 0.034151025, 'SH601888': {'total_score': 0.9361988, 'relation': ['投资', '同行业', '合作', '供应'], 'events': {}}, 'SH601688': {'total_score': 0.5138409, 'relation': ['增加持股'], 'events': {}}, 'SH601211': {'total_score': 0.4987488, 'relation': ['合作'], 'events': {'2024-02-23': ['国泰君安：2024年钢铁行业需求有望超出市场预期', '国泰君安：煤炭股行情背后的逻辑早已摆脱传统的投资框架', '国泰君安：日经指数或将实现23%全年收益', '高新发展今日涨停 国泰君安上海分公司净买入1.21亿元'], '2024-02-22': ['国泰君安：脑机接口突破助推AI多模态发展'], '2024-02-21': ['国泰君安：乘用车板块进入预期修复期', '平安银行巨量涨停 国泰君安上海分公司买入2.16亿元', '国泰君安：下调迎驾贡酒目标价至80元，维持“增持”评级'], '2024-02-20': ['国泰君安：白酒板块2024年估值体系有望企稳甚至回升', '国泰君安：Sora拉大算力缺口 关注国产算力机遇'], '2024-02-19': ['国泰君安：OpenAI发布Sora模型 实现AIGC领域的里程碑式进展', '国泰君安：从“交易底”到“预期底”，市场风格走向均衡...', '国泰君安：重视低风险特征稳定板块时，兼顾成长主题投资线索'], '2024-02-18': ['国泰君安：预计节后A股会延续节前趋势继续中级反弹']}}}, 'SH600010': {'pred_result': 0.10602176, 'SH603799': {'total_score': 0.65351874, 'relation': ['同行业'], 'events': {}}, 'SH601988': {'total_score': 0.499325, 'relation': ['争议'], 'events': {}}, 'SH600019': {'total_score': 0.49807978, 'relation': ['板材', '合作'], 'events': {}}}, 'SH600011': {'pred_result': -0.13734838, 'SH600547': {'total_score': 0.5434777, 'relation': ['上升'], 'events': {}}, 'SH600023': {'total_score': 0.5175704, 'relation': ['同行业'], 'events': {'2024-02-18': ['浙能电力等超50亿成立股权投资合伙企业']}}, 'SH600011': {'total_score': 0.49972567, 'relation': ['同行业', '增加持股', '合作', '争议', '下降', '减少持股', '上升', '供应'], 'events': {}}}, 'SH600015': {'pred_result': -0.041015565, 'SH600030': {'total_score': 0.621189, 'relation': ['合作'], 'events': {'2024-02-23': ['中信证券：Sora横空出世 关注三条投资主线', '中信证券：兼具成长性和业绩兑现能力的国内铜矿股票的估值水平具备提升潜力', '中信证券：Sora发布 关注算力+应用+AI监管', '中信证券：兼具成长性和业绩兑现能力的国内铜矿股票的估...'], '2024-02-20': ['中信证券：人形机器人能力提升 开启应用场景落地序幕', '中信证券不到两月已主动撤回7个IPO保荐 去年投行业务多次收罚单']}}, 'SH600016': {'total_score': 0.5923861, 'relation': ['股份制银行Ⅲ', '同行业'], 'events': {'2024-02-16': ['民生银行：已收到城市房地产融资协调机制推送项目867个 积极推动相关工作落实到位', '民生银行：已收到城市房地产融资协调机制推送项目867个 ...']}}, 'SZ002142': {'total_score': 0.5780264, 'relation': ['同行业'], 'events': {'2024-02-12': ['35股获券商买入评级 宁波银行目标涨幅达105.63%']}}}, 'SH600016': {'pred_result': 0.14060305, 'SH601688': {'total_score': 0.5408047, 'relation': ['增加持股'], 'events': {}}, 'SH601868': {'total_score': 0.5239829, 'relation': ['合作'], 'events': {}}, 'SZ002736': {'total_score': 0.5226147, 'relation': ['同行业'], 'events': {}}}, 'SH600018': {'pred_result': 0.05787974, 'SH600018': {'total_score': 0.57889503, 'relation': ['同行业', '增加持股', '合作', '减少持股', '上升'], 'events': {}}, 'SH601229': {'total_score': 0.49927104, 'relation': ['增加持股', '减少持股'], 'events': {}}, 'SH601988': {'total_score': 0.49912286, 'relation': ['合作'], 'events': {}}}, 'SH600019': {'pred_result': 0.044692956, 'SH600010': {'total_score': 0.7070863, 'relation': ['板材', '合作'], 'events': {}}, 'SH601688': {'total_score': 0.5381172, 'relation': ['增加持股'], 'events': {}}, 'SH601788': {'total_score': 0.52588964, 'relation': ['增加持股', '上升'], 'events': {}}}, 'SH600023': {'pred_result': 0.13217416, 'SH600795': {'total_score': 0.5398389, 'relation': ['火力发电'], 'events': {}}, 'SH600011': {'total_score': 0.49936542, 'relation': ['同行业'], 'events': {}}, 'SH601985': {'total_score': 0.49790934, 'relation': ['同行业'], 'events': {}}}, 'SH600025': {'pred_result': -0.056292385, 'SH600919': {'total_score': 0.744232, 'relation': ['同行业'], 'events': {}}, 'SH600025': {'total_score': 0.56 ...
# {'2024-04-10': dict_keys(['SH603019', 'SH601138', 'SH601059', 'SZ000938', 'SH688256', 'SH600745', 'SH601601', 'SZ002050', 'SZ002475', 'SH601360', 'SZ300782', 'SH601698', 'SZ300033', 'SZ000792', 'SZ002410', 'SH600570', 'SH688561', 'SH600600', 'SH601766', 'SZ301269', 'SH688012', 'SZ002459', 'SH600436', 'SZ000733', 'SH601615', 'SZ002049', 'SZ300661', 'SH601390', 'SZ002415', 'SZ300316', 'SH600460', 'SZ300274', 'SH601319', 'SH601800', 'SZ002236', 'SH601868', 'SZ300454', 'SH688041', 'SZ002241', 'SH603486', 'SH600039', 'SZ002230', 'SH688599', 'SZ002736', 'SZ002555', 'SZ000858', 'SH601117', 'SZ000596', 'SZ000977', 'SH601155', 'SZ000063', 'SH603369', 'SH688187', 'SH600176', 'SH688363', 'SZ300759', 'SH600150', 'SH600183', 'SH603986', 'SH603288', 'SZ000800', 'SZ300122', 'SZ000166', 'SH688223', 'SH601012', 'SZ002371', 'SH601318', 'SH603259', 'SZ002938', 'SH601728', 'SH600918', 'SH601688', 'SH601186', 'SH601881', 'SZ000661', 'SZ002841', 'SH601877', 'SH600030', 'SH601838', 'SZ002129', 'SH601888', 'SH600760', 'SH603806', 'SZ300015', 'SZ300433', 'SH688065', 'SZ002142', 'SH600588', 'SZ300408', 'SZ000768', 'SH600050', 'SZ000651', 'SZ000963', 'SZ300142', 'SH601808', 'SH600016', 'SZ300413', 'SH601669', 'SZ002252', 'SZ300896', 'SH600023', 'SH600584', 'SZ300223', 'SZ002601', 'SZ002304', 'SZ002271', 'SZ300124', 'SZ002001', 'SH601788', 'SZ002007', 'SZ001979', 'SH603799', 'SH600028', 'SZ300750', 'SH600919', 'SZ300014', 'SH600406', 'SZ300059', 'SH688303', 'SZ300760', 'SH601668', 'SH600196', 'SZ000786', 'SH600010', 'SH600893', 'SH601009', 'SZ000001', 'SZ000002', 'SZ000876', 'SH601628', 'SH688126', 'SZ000725', 'SZ002466', 'SH688008', 'SH601377', 'SZ300496', 'SH600989', 'SZ000568', 'SH600061', 'SH600690', 'SH688981', 'SH600999', 'SH601658', 'SZ002493', 'SH600606', 'SH605117', 'SH603290', 'SZ000617', 'SZ002714', 'SZ002202', 'SH601878', 'SZ002812', 'SH600489', 'SH600795', 'SH601100', 'SH603392', 'SH600905', 'SH600018', 'SH601336', 'SH600585', 'SH601021', 'SH601901', 'SH600515', 'SH688036', 'SH601607', 'SH600938', 'SH688111', 'SZ000408', 'SH600438', 'SH600332', 'SH603501', 'SH601995', 'SZ002352', 'SH600019', 'SH601989', 'SH600426', 'SZ000338', 'SH600875', 'SZ300999', 'SH600115', 'SH600741', 'SZ001289', 'SH600837', 'SH600048', 'SH600900', 'SH600009', 'SZ002594', 'SH601169', 'SZ000895', 'SZ000069', 'SZ000333', 'SH600372', 'SH600886', 'SH601236', 'SH600104', 'SH601916', 'SH601799', 'SH601618', 'SH603899', 'SH601229', 'SH601865', 'SH600887', 'SH600809', 'SH601288', 'SZ300957', 'SZ002074', 'SH600029', 'SH601211', 'SH601816', 'SZ002603', 'SH603833', 'SZ000999', 'SZ000301', 'SH601818', 'SH601166', 'SZ300498', 'SH600111', 'SH600845', 'SH601398', 'SH600219', 'SZ002311', 'SH600941', 'SZ300751', 'SZ002648', 'SH601988', 'SH688271', 'SH688396', 'SZ002179', 'SZ002460', 'SH600000', 'SH605499', 'SH601919', 'SH600926', 'SH600085', 'SH601939', 'SH600674', 'SZ300308', 'SH600015', 'SH601689', 'SH600025', 'SH600089', 'SZ300450', 'SH601111', 'SH600519', 'SH601699', 'SH601600', 'SH601328', 'SH601633', 'SZ000538', 'SH600958', 'SZ000625', 'SH600346', 'SH600036', 'SH601006', 'SH603195', 'SH601066', 'SZ000877', 'SH600276', 'SH600309', 'SZ000100', 'SZ002821', 'SH601899', 'SH600660', 'SZ002027', 'SZ002920', 'SZ002180', 'SZ000157', 'SZ000776', 'SH600011', 'SH601872', 'SH603260', 'SH601998', 'SH600754', 'SZ300347', 'SZ003816', 'SH600803', 'SH600031', 'SH601088', 'SH600233', 'SZ300919', 'SZ000708', 'SZ000983', 'SH600132', 'SH601898', 'SH603659', 'SH601225', 'SH601985', 'SZ000425', 'SH600547', 'SZ002916', 'SH603993', 'SZ300628', 'SH601857', 'SH600732', 'SH600188', 'SZ002709', 'SZ300763', 'SZ300979', 'SH601238', 'SH600362']), '2024-04-11': dict_keys(['SH688561', 'SH600460', 'SZ300957', 'SH600436', 'SH600183', 'SZ300316', 'SH601059', 'SZ300759', 'SH688012', 'SZ002241', 'SZ002050', 'SH601155', 'SH603899', 'SZ002493', 'SZ002821', 'SZ002410', 'SH601117', 'SZ002714', 'SZ300496', 'SH688363', 'SZ000408', 'SH601319', 'SH601698', 'SH688223', 'SZ002459', 'SZ002049', 'SZ002129', 'SH603290', 'SZ000617', ...

# %%
from Explanation.ExplanationInterface import run_xpath_explanation
args.explainer = 'xpathExplainer'
exp_result_dict, sorted_stock_rank, _ = run_xpath_explanation(args, events_data, get_fidelity=False, top_k=3)
print(exp_result_dict)
# Out:
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]D:\ProgramFiles\Miniconda\envs\qlib\lib\site-packages\dgl\dataloading\dataloader.py:1149: DGLWarning: Dataloader CPU affinity opt is not enabled, consider switching it on (see enable_cpu_affinity() or CPU best practices for DGL [https://docs.dgl.ai/tutorials/cpu/cpu_best_practises.html])
#   dgl_warning(
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [03:42<00:00, 111.14s/it]
# {'2024-04-10': {'SH600000': {'SH603019': {'total_score': 55, 'relations': ['合作'], 'events': {}}, 'SZ001979': {'total_score': 31, 'relations': ['同行业'], 'events': {}}, 'SZ002142': {'total_score': 12, 'relations': ['同行业'], 'events': {'2024-02-12': ['35股获券商买入评级 宁波银行目标涨幅达105.63%']}}}, 'SH600009': {'SH601888': {'total_score': 82, 'relations': ['投资', '同行业', '合作', '供应'], 'events': {}}, 'SH603799': {'total_score': 9, 'relations': ['上升'], 'events': {}}, 'SZ000333': {'total_score': 7, 'relations': ['同行业'], 'events': {'2024-02-19': ['北上资金今日净买入贵州茅台9.40亿元、美的集团4.23亿元']}}}, 'SH600010': {'SH601988': {'total_score': 41, 'relations': ['争议'], 'events': {}}, 'SH600019': {'total_score': 30, 'relations': ['板材', '合作'], 'events': {}}, 'SH603799': {'total_score': 27, 'relations': ['同行业'], 'events': {}}}, 'SH600011': {'SH600030': {'total_score': 42, 'relations': ['同行业', '争议'], 'events': {'2024-02-23': ['中信证券：Sora横空出世 关注三条投资主线', '中信证券：兼具成长性和业绩兑现能力的国内铜矿股票的估值水平具备提升潜力', '中信证券：Sora发布 关注算力+应用+AI监管', '中信证券：兼具成长性和业绩兑现能力的国内铜矿股票的估...'], '2024-02-20': ['中信证券：人形机器人能力提升 开启应用场景落地序幕', '中信证券不到两月已主动撤回7个IPO保荐 去年投行业务多次收罚单']}}, 'SH601865': {'total_score': 31, 'relations': ['上升'], 'events': {}}, 'SH601600': {'total_score': 26, 'relations': ['减少持股'], 'events': {}}}, 'SH600015': {'SH600030': {'total_score': 46, 'relations': ['合作'], 'events': {'2024-02-23': ['中信证券：Sora横空出世 关注三条投资主线', '中信证券：兼具成长性和业绩兑现能力的国内铜矿股票的估值水平具备提升潜力', '中信证券：Sora发布 关注算力+应用+AI监管', '中信证券：兼具成长性和业绩兑现能力的国内铜矿股票的估...'], '2024-02-20': ['中信证券：人形机器人能力提升 开启应用场景落地序幕', '中信证券不到两月已主动撤回7个IPO保荐 去年投行业务多次收罚单']}}, 'SH600016': {'total_score': 29, 'relations': ['股份制银行Ⅲ', '同行业'], 'events': {'2024-02-16': ['民生银行：已收到城市房地产融资协调机制推送项目867个 积极推动相关工作落实到位', '民生银行：已收到城市房地产融资协调机制推送项目867个 ...']}}, 'SZ000001': {'total_score': 24, 'relations': ['股份制银行Ⅲ'], 'events': {'2024-02-21': ['平安银行突然拉升涨停 该行投资者热线：无应披露而未披露信息', '平安银行涨停 成交额超35亿元', '平安银行巨量涨停 国泰君安上海分公司买入2.16亿元', '平安银行盘中涨停', '大金融板块持续走高 平安银行涨超8%', '平安银行行长特别助理蔡新发离职 公茂江拟任上海分行行长', '平安银行今日涨停 方新侠席位净买入1.31亿元', '平安银行回应涨停：目前无应披露而未披露信息', '银行股震荡拉升，中国银行、农业银行再创历史新高，平安银行、成都银行、齐鲁银行涨超2%'], '2024-02-19': ['平安银行变阵：架构改革路线图浮出水面 管理干部发生批量变动'], '2024-02-22': ['平安银行涨停领涨 银行股估值修复持续演绎']}}}, 'SH600016': {'SH601688': {'total_score': 36, 'relations': ['增加持股'], 'events': {}}, 'SZ002230': {'total_score': 34, 'relations': ['合作'], 'events': {}}, 'SH601916': {'total_score': 28, 'relations': ['股份制银行Ⅲ', '同行业', '下降'], 'events': {'2024-02-18': ['浙商银行：已高效对接24个项目名单 提供融资25亿元']}}}, 'SH600018': {'SZ000001': {'total_score': 42, 'relations': ['减少持股'], 'events': {'2024-02-21': ['平安银行突然拉升涨停 该行投资者热线：无应披露而未披露信息', '平安银行涨停 成交额超35亿元', '平安银行巨量涨停 国泰君安上海分公司买入2.16亿元', '平安银行盘中涨停', '大金融板块持续走高 平安银行涨超8%', '平安银行行长特别助理蔡新发离职 公茂江拟任上海分行行长', '平安银行今日涨停 方新侠席位净买入1.31亿元', '平安银行回应涨停：目前无应披露而未披露信息', '银行股震荡拉升，中国银行、农业银行再创历史新高，平安银行、成都银行、齐鲁银行涨超2%'], '2024-02-19': ['平安银行变阵：架构改革路线图浮出水面 管理干部发生批量变动'], '2024-02-22': ['平安银行涨停领涨 银行股估值修复持续演绎']}}, 'SH601658': {'total_score': 30, 'relations': ['同行业'], 'events': {}}, 'SH600104': {'total_score': 26, 'relations': ['合作'], 'events': {}}}, 'SH600019': {'SH600845': {'total_score': 49, 'relations': ['投资', '供应'], 'events': {}}, 'SH600010': {'total_score': 45, 'relations': ['板材', '合作'], 'events': {}}, 'SH601857': {'total_score': 5, 'relations': ['同行业'], 'events': {}}}, 'SH600023': {'SH600023': {'total_score': 66, 'relations': ['火力发电', '同行业'], 'events': {'2024-02-18': ['浙能电力等超50亿成立股权投资合伙企业']}}, 'SH601985': {'total_score': 24, 'relations': ['同行业'], 'events': {}}, 'SH600011': {'total_score': 8, 'relations': ['同行业'], 'events': {}}}, 'SH600025': {'SH600025': {'total_score': 40, 'relations': ['水力发电', '同行业'], 'events': {}}, 'SH600674': {'total_score': 30, 'relations': ['水力发电'], 'events': {}}, 'SH600919': {'total_score': 29, 'relations': ['同行业'], 'events': {}}}, 'SH600028': {'SH603019': {'total_score': 48, 'relations': ['供应'], 'events': {}}, 'SZ002648': {'total_score': 26, 'relations': ['同行业'], 'events': {}}, 'SH600030': {'total_score': 24, 'relations': ['争议', '下降'], 'events': {'2024-02-23': ['中信证券：Sora横空出世 关注三条投资主线', '中信证券：兼具成长性和业绩兑现能力的国内铜矿股票的估值水平具 ...

# %%
from Explanation.ExplanationInterface import run_gnn_explainer
args.explainer = 'gnnExplainer'
exp_result_dict, sorted_stock_rank, _ = run_gnn_explainer(args, events_data, top_k=3)
print(exp_result_dict)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [17:04<00:00, 512.23s/it]
# {'2024-04-10': {'SH600000': {'SH600000': {'total_score': 2.5647318363189697, 'relations': ['股份制银行Ⅲ', '同行业', '增加持股', '合作', '争议', '下降', '上升', '供应', '竞争'], 'events': {'2024-02-11': ['浦发银行全面推进落实城市房地产融资协调机制']}}, 'SH600036': {'total_score': 0.9683955907821655, 'relations': ['股份制银行Ⅲ', '同行业', '下降'], 'events': {'2024-02-14': ['招商银行H股涨5%领涨内银股'], '2024-02-21': ['北上资金今日净买入贵州茅台13.86亿元、招商银行7.71亿元，净卖出三花智控3.43亿元、长安汽车0.97亿元']}}, 'SH601988': {'total_score': 0.9572372436523438, 'relations': ['同行业', '增加持股', '争议'], 'events': {}}}, 'SH600009': {'SH600009': {'total_score': 2.108368396759033, 'relations': ['机场', '投资', '同行业', '增加持股', '合作', '下降', '上升', '供应'], 'events': {}}, 'SH601888': {'total_score': 0.9603880643844604, 'relations': ['投资', '同行业', '合作', '供应'], 'events': {}}, 'SH600276': {'total_score': 0.45386701822280884, 'relations': ['增加持股'], 'events': {}}}, 'SH600010': {'SH600010': {'total_score': 2.7585153579711914, 'relations': ['板材', '投资', '同行业', '增加持股', '合作', '争议', '下降', '上升', '优越的', '供应'], 'events': {}}, 'SH600111': {'total_score': 2.2813265323638916, 'relations': ['投资', '同行业', '增加持股', '合作', '争议', '上升', '优越的', '供应'], 'events': {}}, 'SH601988': {'total_score': 0.5941280722618103, 'relations': ['争议'], 'events': {}}}, 'SH600011': {'SH600011': {'total_score': 2.2438457012176514, 'relations': ['同行业', '增加持股', '合作', '争议', '下降', '减少持股', '上升', '供应'], 'events': {}}, 'SH600875': {'total_score': 0.9547543525695801, 'relations': ['增加持股', '下降', '上升'], 'events': {}}, 'SZ002202': {'total_score': 0.5728931427001953, 'relations': ['下降', '上升'], 'events': {}}}, 'SH600015': {'SH600015': {'total_score': 1.7057451009750366, 'relations': ['股份制银行Ⅲ', '同行业', '合作', '争议', '优越的', '供应'], 'events': {'2024-02-23': ['银行股震荡拉升 华夏银行涨超5%'], '2024-02-22': ['华夏银行业绩快报：2023年净利润263.63亿元 同比增长5.3%', '华夏银行业绩快报：2023年度净利润同比增长5.3%'], '2024-02-18': ['因采用不正当手段发放贷款等 华夏银行北京分行被罚461万'], '2024-02-16': ['华夏银行对接城市房地产融资协调机制已批复项目15个']}}, 'SH601998': {'total_score': 1.0496516227722168, 'relations': ['股份制银行Ⅲ', '同行业', '合作', '供应'], 'events': {}}, 'SH600016': {'total_score': 0.6551846861839294, 'relations': ['股份制银行Ⅲ', '同行业'], 'events': {'2024-02-16': ['民生银行：已收到城市房地产融资协调机制推送项目867个 积极推动相关工作落实到位', '民生银行：已收到城市房地产融资协调机制推送项目867个 ...']}}}, 'SH600016': {'SH600016': {'total_score': 3.2003135681152344, 'relations': ['股份制银行Ⅲ', '投资', '同行业', '增加持股', '合作', '争议', '下降', '减少持股', '上升', '优越的', '供应'], 'events': {'2024-02-16': ['民生银行：已收到城市房地产融资协调机制推送项目867个 积极推动相关工作落实到位', '民生银行：已收到城市房地产融资协调机制推送项目867个 ...']}}, 'SH601988': {'total_score': 1.298584222793579, 'relations': ['投资', '同行业', '增加持股', '争议'], 'events': {}}, 'SH600036': {'total_score': 0.8615237474441528, 'relations': ['股份制银行Ⅲ', '争议', '上升'], 'events': {'2024-02-14': ['招商银行H股涨5%领涨内银股'], '2024-02-21': ['北上资金今日净买入贵州茅台13.86亿元、招商银行7.71亿元，净卖出三花智控3.43亿元、长安汽车0.97亿元']}}}, 'SH600018': {'SH600018': {'total_score': 1.094132900238037, 'relations': ['同行业', '增加持股', '合作', '减少持股', '上升'], 'events': {}}, 'SH601229': {'total_score': 0.5537118911743164, 'relations': ['增加持股', '减少持股'], 'events': {}}, 'SH601919': {'total_score': 0.35720711946487427, 'relations': ['合作'], 'events': {'2024-02-21': ['中远海控：斥资约1151万港元回购135万股']}}}, 'SH600019': {'SH600019': {'total_score': 2.6479897499084473, 'relations': ['板材', '投资', '同行业', '增加持股', '合作', '下降', '上升', '优越的', '供应'], 'events': {}}, 'SH600845': {'total_score': 0.6086432933807373, 'relations': ['投资', '供应'], 'events': {}}, 'SH601788': {'total_score': 0.5173793435096741, 'relations': ['增加持股', '上升'], 'events': {}}}, 'SH600023': {'SH600023': {'total_score': 0.4656698703765869, 'relations': ['火力发电', '同行业'], 'events': {'2024-02-18': ['浙能电力等超50亿成立股权投资合伙企业']}}, 'SH600795': {'total_score': 0.297617644071579, 'relations': ['火力发电'], 'events': {}}, 'SH600011': {'total_score': 0.21985702216625214, 'relations': ['同行业'], 'events': {}}}, 'SH600025': {'SH600025': {'total_score': 0.827700138092041, 'relations': ['水力发电', '同行业'], 'events': {}}, 'SH600900': {'total_score': 0.25785014033317566, 'relations': ['水力发电'], 'events': {'2024-02-19': ['长江电力：世界最大清洁能源走廊六座梯级电站累计发电量突破35000亿千瓦时']} ...
